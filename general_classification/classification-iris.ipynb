# %%
import pandas as pd
from sklearn import datasets
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use("dark_background")

dat = datasets.load_iris()

iris = pd.DataFrame(dat['data'], columns=dat['feature_names'])
iris['species'] = dat['target']

# %%
# target_name_dict = {}
# for i, v in enumerate(dat['target_names']):
#     target_name_dict[i] = v

# iris['species_name'] = iris['species'].map(target_name_dict)
# iris['species'] = iris['species'].astype('str')

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris, hue='species', palette='Greens')

# %%
y = iris['species']
X = iris.drop(columns='species')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30, random_state=42)

# %%
from sklearn import ensemble

clr = ensemble.RandomForestClassifier(n_estimators=1000, random_state=20)
clr.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=20)

# %%
probs = clr.predict_proba(X_test)

# %%
prob_0 = probs[:, 0]
prob_1 = probs[:, 1]
prob_2 = probs[:, 2]

# %%
evaluate = pd.DataFrame({
    'actual': y_test,
    'prob_0': prob_0,
    'prob_1': prob_1,
    'prob_2': prob_2,
    'predicted': clr.predict(X_test)
})

evaluate
# Out:
#      actual  prob_0  prob_1  prob_2  predicted
# 73        1   0.000   0.988   0.012          1
# 18        0   0.967   0.033   0.000          0
# 118       2   0.000   0.013   0.987          2
# 78        1   0.000   0.981   0.019          1
# 76        1   0.000   0.845   0.155          1
# 31        0   0.992   0.008   0.000          0
# 64        1   0.000   1.000   0.000          1
# 141       2   0.000   0.076   0.924          2
# 68        1   0.000   0.864   0.136          1
# 82        1   0.000   0.999   0.001          1
# 110       2   0.000   0.075   0.925          2
# 12        0   0.998   0.001   0.001          0
# 36        0   0.952   0.048   0.000          0
# 9         0   0.999   0.001   0.000          0
# 19        0   1.000   0.000   0.000          0
# 56        1   0.008   0.898   0.094          1
# 104       2   0.000   0.001   0.999          2
# 69        1   0.000   0.999   0.001          1
# 55        1   0.000   0.988   0.012          1
# 132       2   0.000   0.000   1.000          2
# 29        0   1.000   0.000   0.000          0
# 127       2   0.000   0.092   0.908          2
# 26        0   1.000   0.000   0.000          0
# 128       2   0.000   0.000   1.000          2
# 131       2   0.001   0.002   0.997          2
# 145       2   0.000   0.028   0.972          2
# 108       2   0.000   0.034   0.966          2
# 143       2   0.000   0.002   0.998          2
# 45        0   0.998   0.001   0.001          0
# 30        0   0.999   0.001   0.000          0
# 22        0   1.000   0.000   0.000          0
# 15        0   0.967   0.033   0.000          0
# 65        1   0.003   0.994   0.003          1
# 11        0   1.000   0.000   0.000          0
# 42        0   1.000   0.000   0.000          0
# 146       2   0.000   0.066   0.934          2
# 51        1   0.006   0.972   0.022          1
# 27        0   0.998   0.002   0.000          0
# 4         0   1.000   0.000   0.000          0
# 32        0   0.999   0.001   0.000          0
# 142       2   0.000   0.043   0.957          2
# 85        1   0.016   0.906   0.078          1
# 86        1   0.003   0.992   0.005          1
# 16        0   0.998   0.002   0.000          0
# 10        0   0.998   0.002   0.000          0
