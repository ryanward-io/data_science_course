# %%
import pandas as pd

# read the data
houses = pd.read_csv("./train.csv")

# drop the id columns
houses = houses.drop(columns="Id")

houses
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
Xy = houses.dropna(axis=1)

# %%
cat_list = []

for col, v in dict(zip(Xy.columns.tolist(), (Xy.dtypes == "object").tolist())).items():
    if v:
        cat_list.append(col)

# these are our first 10 categorical columns
cat_list[:10]
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2']

# %%
from sklearn import preprocessing

# this is a categorical data
cat_data = Xy[cat_list]

# one hot encoding
ohc = preprocessing.OneHotEncoder(handle_unknown='ignore')

X_cat = ohc.fit_transform(cat_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-f3258381f793> in <module>()
#       7 ohc = preprocessing.OneHotEncoder(handle_unknown='ignore')
#       8
# ----> 9 X_cat = ohc.fit_transform(cat_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit_transform(self, X, y)
#    2017         """
#    2018         return _transform_selected(X, self._fit_transform,
# -> 2019                                    self.categorical_features, copy=True)
#    2020
#    2021     def _transform(self, X):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in _transform_selected(X, transform, selected, copy)
#    1807     X : array or sparse matrix, shape=(n_samples, n_features_new)
#    1808     """
# -> 1809     X = check_array(X, accept_sparse='csc', copy=copy, dtype=FLOAT_DTYPES)
#    1810
# ...

# %%
Xy_clean = pd.concat(
    [pd.DataFrame(X_cat.todense())
     , Xy.drop(columns=cat_list)], axis=1
)
